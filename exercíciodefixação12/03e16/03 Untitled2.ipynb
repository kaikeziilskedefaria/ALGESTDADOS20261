# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/exerc%C3%ADciodefixa%C3%A7%C3%A3o12/03e16/03%20Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.
a = 15
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
#2 Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra:
# A - quantos grupos completos serão formados
print(f" Formarão: {37//5}")
# B - quantos alunos sobrarão
print(f" Sobrarão: {37 % 5} alunos")
# Out:
#  Formarão: 7
#  Sobrarão: 2 alunos

# %%
#3 Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem
base = 8.5
altura = 3.2
print(f" A área do retangulo é: {(base*altura):.2f}")
# Out:
#  A área do retangulo é: 27.20

# %%
#4 Dado o valor: segundos = 9875 Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída:
segundos = 9875
minutos = segundos//60
segundos = segundos%60
horas = minutos//60
minutos = minutos%60
print(f"{horas}h {minutos}m e {segundos}s")
# Out:
# 2h 44m e 35s

# %%
#5 Calcule: 2 ** 10
#Explique com um comentário no código o que essa operação representa.
#R.: O número dois é elevado a sua 10° potência

#Depois calcule a raiz quadrada de 144 usando potenciação.
print(f"A raiz de 144 é: {144**(1/2)}")
# Out:
# A raiz de 144 é: 12.0

# %%
#6 Crie uma variável: temperatura = 38.5
temperatura = 38.5
#se a temperatura é maior que 37.5
print(temperatura>37.5)
#se a temperatura é igual a 36.5
print(temperatura==37.5)
#se a temperatura é diferente de 40.0
print(temperatura!=40)
# Out:
# True
# False
# True

# %%
#7 Dados:
x = 10
y = 10
#Preveja o resultado antes de executar e depois confirme no Python:
print(x == y)#true
print(x != y)#false
print(x >= y)#true
print(x <= y + 1)#true
# Out:
# True
# False
# True
# True

# %%
#8 Um aluno tirou nota 6.5. Usando operadores relacionais, verifique se ele:
nota = 6.5
#foi aprovado (>= 7.0)
print(f" Ele foi aprovado? {nota>=7}")
#está em recuperação (>= 5.0 e < 7.0)
print(f" Ele Está em recuperação? {(nota<7)and(nota>=5)}")
#foi reprovado (< 5.0)
print(f" Ele foi reprovado? {nota<5}")
# Out:
#  Ele foi aprovado? False
#  Ele Está em recuperação? True
#  Ele foi reprovado? False

# %%
#9 Declare:
a = 5
b = "5"
(a==b)
#Compare:
a == b
#Explique o resultado com um comentário no código.
#False. Porque o a está em formato inteiro e o b em formato de texto.
# Out:
# False

# %%
#10 Crie um programa com:
preco = 49.90
#Verifique se o produto está dentro do orçamento de R$ 50,00 usando <=.

# %%
#11 Uma pessoa pode votar se tiver 16 anos ou mais.
idade1 = 15
idade2 = 18 # Definindo idade2 antes de ser usada
print(f"Com {idade1} anos pode votar? {idade1>=16}")
print(f"Com {idade2} anos pode votar? {idade2>=16}")
#Use operadores lógicos para verificar se ela não pode votar.
print(f"Com {idade1} anos não pode votar? {idade1<16}")
print(f"Com {idade2} anos não pode votar? {idade2<16}")
# Out:
# Com 15 anos pode votar? False
# Com 18 anos pode votar? True
# Com 15 anos não pode votar? True
# Com 18 anos não pode votar? False

# %%
#12 Um empréstimo é aprovado se:
#renda >= 2000
#score >= 700
#Teste pelo menos três combinações diferentes usando and.

#Teste 1
renda = 1900 #renda menor
score = 500 #score menor
print(f"Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado {score >= 700 and renda >= 2000}")

#teste 2
renda = 4000 #renda maior
score = 700 #score igual
print(f"Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado {score >= 700 and renda >= 2000}")

#teste 3
renda = 1500 #renda maior
score = 850 #score menor
print(f"Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado {score >= 700 and renda >= 2000}")
# Out:
# Meu score é 500 e minha renda é R$1900. Empréstimo aprovado False
# Meu score é 700 e minha renda é R$4000. Empréstimo aprovado True
# Meu score é 850 e minha renda é R$1500. Empréstimo aprovado False

# %%
#13 Um sistema libera acesso se o usuário for administrador ou tiver nível de acesso ≥ 3.
#is_admin = False
#nivel_acesso = 4
#Use o operador or.
nível = int(input("Qual seu nível de acesso"))
admin = bool(input("Você é administrador?"))
print(f"Acesso liberado?{nível>=3 or admin==true}")
# Out:
# Qual seu nível de acesso5
# Você é administrador?não
# Acesso liberado?True

# %%
#14Dado:
chovendo = True
#Use not para verificar se não está chovendo. Depois combine com uma verificação de temperatura maior que 25.
print(f"Está chovendo? {not chovendo} \ne a temperatura é maior que 25°C? {temperatura>25}")
# Out:
# Está chovendo? False
# e a temperatura é maior que 25°C? True

# %%
#15 Monte manualmente a tabela-verdade do operador and:
print("Tabela-verdade do operador AND");
print(" A         B     C")
print(f"True and True = {True and True}")
print(f"True and False = {True and False}")
print(f"False and True = {False and True}")
print(f"False and False = {False and False}")
# Out:
# Tabela-verdade do operador AND
#  A         B     C
# True and True = True
# True and False = False
# False and True = False
# False and False = False

# %%
#16 Calcule manualmente antes de executar:
# A - 5 + 2 * 3 #11
# B - (5 + 2) * 3 #21
# C - 2 ** 3 ** 2 #256
# D - 10 - 4 / 2 + 1 #9
#Explique a ordem de execução nos comentários.
print(5 + 2 * 3) #11
print((5 + 2) * 3 )#21
print(2 ** 3 ** 2) #512
print(10 - 4 / 2 + 1) #9
# Out:
# 11
# 21
# 512
# 9.0

# %%
#17Resolva passo a passo:
resultado = 3 + 2 * 4 ** 2 - 1

#1° passo > 4 ** 2 = 16 ou seja o resultado = 3 + 2 * 16 - 1
#2 passo > 16 * 2 = 32 ou seja, resultado = 3 + 32 - 1
#3 passo > 3 + 32  - 1 = 34 ou seja, resultado = 34
print(resultado)
#Reescreva usando parênteses para mostrar a ordem das operações.
resultado = 3 + (2*(4**2))-1
# Out:
# 34

# %%
#18 Analise o resultado da expressão abaixo antes de executar:
x = 4 + 3 * 2 > 9 and not (5 == 5)
print(x)
#Resposta: para a expressão AND ser False, basta que uma das proposições "not(5==5)" seja False
# Out:
# False

# %%
#19 Reescreva usando parênteses para obter os resultados indicados:
a = 10 / (2 + 3)

b = not True or False
print(b)#False
# Out:
# False

# %%
#20 Crie uma expressão que use operadores aritméticos, relacionais e lógicos para resolver o problema:
#Um estudante é aprovado com distinção se a média de duas notas for maior ou igual a 9.0 e nenhuma das notas
#for menor que 7.0.

nota1 = 9.5
nota2 = 8.5
media = (nota1+nota2)/2
print(f' Está aprovado? {media>=9 and nota1 >= 7 and nota2 >=7}')
# Out:
#  Está aprovado? True
