# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/exercicio_de_fixa%C3%A7%C3%A3o/atividade_04_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01
#Contagem de Elementos
#Crie uma lista contendo os nomes de 5 vilões clássicos do Mario. Utilize a função len() para contar o número total
#de itens e exiba o resultado no terminal.

viloes = ["Bowser", "Wario", "Waluigi","King Boo","Kamek",]
print(f"A lista possui {len(viloes)} vilões")
# Out:
# A lista possui 5 vilões

# %%
#02
#Adição Dinâmica
#Inicie uma lista vazia chamada moedas_coletadas. Use um laço de repetição para pedir que o usuário informe 4
#valores inteiros e adicione cada um deles ao final da lista usando append().

moedas_coletadas = [","]
inteiros = int(input("Informe 4 valores inteiros :"))
moedas_coletadas.append(inteiros)
print(moedas_coletadas)
# Out:
# Informe 4 valores inteiros :2368
# [',', 2368]

# %%
#03
#Inserção por Posição
#Crie a lista herois = ['Mario', 'Peach']. Utilize o método insert() para adicionar o nome 'Luigi' exatamente no
#meio da lista (índice 1) e exiba a lista final.

lista = ["Mario","Peach"]
lista.insert(1,"Luigi")
print(lista)
# Out:
# ['Mario', 'Luigi', 'Peach']

# %%
#04
#Exclusão por Nome
#Dada a lista viloes = ['Bowser', 'Goomba', 'Wario', 'Koopa'], solicite que o usuário digite um nome. Se o nome
#estiver na lista, use remove() para excluí-lo.

viloes = ['Bowser', 'Goomba', 'Wario', 'Koopa']
nome = input("Digite um nome: ")
if nome in viloes:
    viloes.remove(nome)
else:
    nome not in viloes
    print("Nome não encontrado")
print(viloes)
# Out:
# Digite um nome: Kaike
# Nome não encontrado
# ['Bowser', 'Goomba', 'Wario', 'Koopa']

# %%
#05
#Remover o Último Elemento
#Crie uma lista com nomes de 4 itens de poder (ex: Estrela, Cogumelo). Use pop() para remover o último item e
#mostre qual item foi removido e como a lista ficou.
poder = ["Estrela", "Cogumelo","Sharingan","Orbes"]
item_removido = poder.pop()
print(f"Item removido: {item_removido}")
print(f"Lista atualizada: {poder}")
# Out:
# Item removido: Orbes
# Lista atualizada: ['Estrela', 'Cogumelo', 'Sharingan']

# %%
pontuacoes = []
for i in range(5):
    score = int(input(f"Digite a {i+1}ª pontuação: "))
    pontuacoes.append(score)

pontuacoes.sort()
print(f"Lista organizada em ordem crescente: {pontuacoes}")
# Out:
# Digite a 1ª pontuação: 45
# Digite a 2ª pontuação: 23
# Digite a 3ª pontuação: 67
# Digite a 4ª pontuação: 43
# Digite a 5ª pontuação: 79
# Lista organizada em ordem crescente: [23, 43, 45, 67, 79]
