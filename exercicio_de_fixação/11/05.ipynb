# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/exercicio_de_fixa%C3%A7%C3%A3o/11/05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01
#Cadastro de Coordenadas
#Crie uma tupla contendo três coordenadas no formato (x, y). Exiba cada coordenada separadamente, calcule a soma
#de todos os valores armazenados e informe qual é o maior número presente na tupla.

# %%
#02
#Produtos sem Repetição
#Leia cinco nomes de produtos digitados pelo usuário e armazene-os em um conjunto. Ao final, exiba todos os
#produtos cadastrados e a quantidade total de itens únicos.

for item in range(5):
    item = input(f" Digite o  {i+1} produto")
    conjunto.add(item)
for item in conjunto:
    print(item)
    print(f" Produtos unicos: {len[conjuntos]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1646/1116445689.py in <cell line: 0>()
#       5
#       6 for item in range(5):
# ----> 7     item = input(f" Digite o  {i+1} produto")
#       8     conjunto.add(item)
#       9 for item in conjunto:
#
# NameError: name 'i' is not defined

# %%
#03
#Analisando uma Tupla
#Crie uma tupla com 6 números inteiros. Exiba a quantidade de números pares, a soma dos números ímpares e o
#menor valor armazenado.
