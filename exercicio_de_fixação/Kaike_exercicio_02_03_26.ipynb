# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/exercicio_de_fixa%C3%A7%C3%A3o/Kaike_exercicio_02_03_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome='Kaike'
idade='19'
print(nome,idade)
# Out:
# Kaike 19

# %%
print(f'meu nome é {nome} e tenho {19}')
# Out:
# meu nome é Kaike e tenho 19

# %%
#Exercicio de fixação
nome_de_usuario = "kaike ziilske de faria"
mensagem_de_boas_vindas = 'bem vindo a engenharia calouro'
print(f"nome de usuário: {nome_de_usuario} e a mensagem de boas vindas: {mensagem_de_boas_vindas}")
# Out:
# nome de usuário: kaike ziilske de faria e a mensagem de boas vindas: bem vindo a engenharia calouro

# %%
#exercicio 3
numeroa = int(input('digite o primeiro número'))
numerob = int(input('digite o primeiro número'))
print(f"{numeroa} + {numerob} = {numeroa + numerob}")
# Out:
# digite o primeiro número1
# digite o primeiro número1
# 1 + 1 = 2

# %%
#exercicio 4
numero = int(input("digite o numero:"))
print(f"Antecessor: {numero - 1} Sucessor: {numero + 1}")
# Out:
# digite o numero:2
# Antecessor: 1 Sucessor: 3

# %%
# exercicio 5 Faça um programa que peça o ano de nascimento do usuário e calcule sua idade aproximada.
anodenascimento = int(input("digite o ano de nascimento:"))
print(f"sua idade é: {2026 - anodenascimento}")
# Out:
# digite o ano de nascimento:2006
# sua idade é: 20

# %%
#exercicio 6 Desenvolva um programa que peça duas notas e calcule a média entre elas.
nota_a = float(input("digite a primeira nota:"))
nota_b = float(input("digite a segunda nota:"))
print(f" A média do aluno é: {(nota_a + nota_b)/2}")
# Out:
# digite a primeira nota:10.5
# digite a segunda nota:10.5
#  A média do aluno é: 10.5

# %%
#exercicio 7 Crie um programa que peça uma temperatura em graus Celsius e converta para Fahrenheit.
valor_em_celsius = float(input("digite o valor em celsius"))
print(f" O valor em faharenty é: {(valor_em_celsius * 1.8) + 32}")
# Out:
# digite o valor em celsius23
#  O valor em faharenty é: 73.4

# %%
#exercicio 8 Faça um programa que peça a largura e a altura de um retângulo e calcule sua área
largura = float(input("digite a largura do retângulo"))
altura = float(input("digite a altura do retângulo"))
print(f" A  área do retângulo é : {largura * altura}")
# Out:
# digite a largura do retângulo5
# digite a altura do retângulo5
#  A  área do retângulo é : 25.0

# %%
#exercicio 9  Desenvolva um programa que peça um número inteiro e calcule o seu quadrado.
numero_1 = int(input("digite o número inteiro"))
print(f" O quadrado do número inteiro : {numero_1*numero_1}")
# Out:
# digite o número inteiro1
#  O quadrado do número inteiro : 1

# %%
#
