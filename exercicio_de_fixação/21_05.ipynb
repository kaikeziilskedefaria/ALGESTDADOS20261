# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/exercicio_de_fixa%C3%A7%C3%A3o/21_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01
#Criando o Primeiro Dicionário
#Crie um dicionário chamado pessoa com as seguintes chaves: nome, idade, cidade e profissao.
#Preencha-o com dados fictícios de uma pessoa qualquer. Em seguida, imprima o dicionário completo no terminal.
pessoa = {
    "nome": "Kaike",
    "idade": 19,
    "cidade": "Nova venécia",
    "profissao": "Engenheiro",
}
print(pessoa)
# Out:
# {'nome': 'Kaike', 'idade': 19, 'cidade': 'Nova venécia', 'profissao': 'Engenheiro'}

# %%
#02
#Acessando Valores por Chave
#Dado o dicionário produto = {"nome": "Caderno", "preco": 15.90, "estoque": 42}, escreva um programa que exiba separadamente o nome
#do produto, o preço e a quantidade em estoque.Use o acesso direto por colchetes para ao menos um valor e o método
#.get() para ao menos um outro.

produto = {"nome": "Caderno", "preco": 15.90, "estoque": 42}
print("Nome: ",produto["nome"])
print("preço: ',produto")["preco"]")

print(produto)
# Out:
# {'nome': 'Caderno', 'preco': '15.90', 'estoque': '42'}
