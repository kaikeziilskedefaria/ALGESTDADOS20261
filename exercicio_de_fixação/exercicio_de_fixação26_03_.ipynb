# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/exercicio_de_fixa%C3%A7%C3%A3o/exercicio_de_fixa%C3%A7%C3%A3o26_03_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Leia a nota de um aluno. Classifique usando elif:
#nota ≥ 9 → "A — Excelente", ≥ 7 → "B — Aprovado", ≥ 5 → "C — Recuperação", abaixo → "D — Reprovado".
nota = float(input("Digite sua Nota:"))
if nota >= 9:
    print("A - Excelente")
elif nota >= 7:
    print("B - Aprovado")
elif nota >= 5:
    print("C - Recuperação")
else:
    print("D - Reprovado")
# Out:
# Digite sua Nota:9
# A - Excelente

# %%
#2 Leia um número de 1 a 7 e exiba o nome
#do dia correspondente (1 = Segunda, ..., 7 = Domingo). Para qualquer outro número, exiba "Número inválido".
dia = int(input("Digite um número de 1 a 7:"))
match dia:
    case 1: print("Segunda Feira")
    case 2: print("Terça Feira")
    case 3: print("Quarta Feira")
    case 4: print("Quinta Feira")
    case 5: print("Sexta Feira")
    case 6: print("Sábado")
    case 7: print("Domingo")
    case _ : print(" Dia da Semana não Existe !")
# Out:
# Digite um número de 1 a 7:7
# Domingo

# %%
#3 Leia uma nota. Valide se está entre 0 e 10 usando encadeamento de comparações
#(0 <= nota <= 10). Se inválida, exiba "Nota inválida!". Se válida, exiba "Nota registrada: [nota]".
nota = float(input("Digite uma nota: "))
if 0 <= nota <= 10:
    print(f"Nota registrada: {nota}")
    print("Nota válida")
else:
    print("Nota inválida!")
# Out:
# Digite uma nota: 6
# Nota registrada: 6.0
# Nota válida

# %%
#4 Leia a idade. Classifique: menor de 12 → "Criança",
#12 a 17 → "Adolescente", 18 a 59 → "Adulto", 60 ou mais → "Idoso". Valide que a idade não é negativa.
idade = int(input("Digite sua idade: "))
if idade < 0 or idade > 120:
    print("Idade inválida!")
elif idade >= 1 and idade < 12:
    print("Criança")
elif idade >= 12 and idade <18:
    print("Adolescente")
elif idade >= 18 and idade <60:
    print("Adulto")
elif idade >= 60:
    print("Idoso")
# Out:
# Digite sua idade: 19
# Adulto

# %%
#5 Exiba um menu com 3 opções (ex: 1-Água R$2, 2-Suco R$6, 3-Café R$4).
#Leia a escolha. Valide com not (1 <= item <= 3). Se inválido, exiba erro; se válido, exiba o item e o preço.
menu = print("1-Água R$2, 2-Suco R$6, 3-Café R$")
