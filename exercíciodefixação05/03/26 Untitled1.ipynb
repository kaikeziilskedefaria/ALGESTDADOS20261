# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/exerc%C3%ADciodefixa%C3%A7%C3%A3o05/03/26%20Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 Peça ao usuário que digite sua idade usando input(), converta o valor para inteiro utilizando int() e exiba na tela a idade somada com 5 anos
x = int(input("digite_sua_idade:"))
print(x+5)
# Out:
# digite_sua_idade:19
# 24

# %%
# 2 Solicite ao usuário sua altura em metros, converta o valor digitado para float e mostre o dobro da altura informada
x = float(input("digite sua altura em metros"))
print(f"o dobro da sua altura é: {(x*2)}")
# Out:
# digite sua altura em metros1.85
# o dobro da sua altura é: 3.7

# %%
# 3 Crie uma variável inteira com valor 100, converta esse valor para str e concatene com a frase " pontos alcançados", exibindo o resultado final.
x = 100
txt = str(x)
print(txt + " pontos alcançados")
# Out:
# 100 pontos alcançados

# %%
# 4 Peça ao usuário que digite 1 para verdadeiro ou 0 para falso, converta primeiro para inteiro e depois para bool, mostrando o valor booleano resultante
x = (input("digite 1 para verdadeiro, digite 0 para falso"))
txt = int(x)
tyt = bool(txt)
print(tyt)
# Out:
# digite 1 para verdadeiro, digite 0 para falso1
# True

# %%
# 5 Peça três números ao usuário, converta todos para inteiro e mostre o maior entre eles.
x = (input("digite o primeiro valor"))
y = (input("digite o segundo valor"))
z = (input("digite o terceiro valor"))
a = (int(x))
b = (int(y))
c = (int(z))
print(max(a,b,c))
# Out:
# digite o primeiro valor1
# digite o segundo valor2
# digite o terceiro valor3
# 3

# %%
# 6 Peça quatro números decimais ao usuário, converta para float e calcule a média aritmética entre eles
a = (input("digite o primeiro número decimal"))
b = (input("digite o segundo número decimal"))
c = (input("digite o terceiro número decimal"))
d = (input("digite o quarto número decimal"))
w = (float(a))
x = (float(b))
y = (float(c))
z = (float(d))
print(f" a média é: {(w+x+y+z)/4}")
# Out:
# digite o primeiro número decimal1.2
# digite o segundo número decimal1.2
# digite o terceiro número decimal1.2
# digite o quarto número decimal1.2
#  a média é: 1.2

# %%
#7 Peça a idade do usuário em anos, converta para inteiro e calcule aproximadamente quantos meses essa pessoa já viveu
x = int(input(" digite sua idade em anos"))
print(f" a quantidade de meses que você viveu é: {(x*12)}")
# Out:
#  digite sua idade em anos19
#  a quantidade de meses que você viveu é: 228

# %%
#8 Peça ao usuário que digite um número inteiro, converta esse número para str e utilize a função len() para mostrar quantos caracteres foram digitados.
x = int(input(" digite um número inteiro"))
y = (str(x))
z = (len(y))
print(f" a quantidade de caracteres escritas é {z}")
# Out:
#  digite um número inteiro54623575875384687
#  a quantidade de caracteres escritas é 17

# %%
#9 ERRADO Escreva um pequeno código que tente somar 1 a um valor recebido por input() sem realizar conversão, observe o erro gerado e depois corrija o código realizando a conversão adequada.
x = input("digite o primeiro número")
print(f" o resultado da soma é igual a {x+1}")
# Out:
# digite o primeiro número2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_185/2926226623.py in <cell line: 0>()
#       1 #9 Escreva um pequeno código que tente somar 1 a um valor recebido por input() sem realizar conversão, observe o erro gerado e depois corrija o código realizando a conversão adequada.
#       2 x = input("digite o primeiro número")
# ----> 3 print(f" o resultado da soma é igual a {x+1}")
#
# TypeError: can only concatenate str (not "int") to str

# %%
#9 CERTO Escreva um pequeno código que tente somar 1 a um valor recebido por input() sem realizar conversão, observe o erro gerado e depois corrija o código realizando a conversão adequada.
x = int(input("digite o primeiro número"))
print(f" o resultado da soma é igual a {x+1}")
# Out:
# digite o primeiro número1
#  o resultado da soma é igual a 2

# %%
#10 Peça um número decimal ao usuário, converta para float e depois converta esse valor para inteiro usando int(), exibindo ambos os resultados para comparar a diferença.
decimal = float(input("digite um número decimal"))
inteiro = int(decimal)
print(f'decimal: {decimal} / inteiro: {inteiro}')
# Out:
# digite um número decimal1.2
# decimal: 1.2 / inteiro: 1

# %%
#11 Solicite um número ao usuário, converta para inteiro e depois para bool, explicando em quais situações o resultado será False.
inteiro = int(input("digite um número"))
boolean = bool(inteiro)
print(f'{boolean}, pois apenas valores 0 ou vazio são false em Pynton')
# Out:
# digite um número1
# True, pois apenas valores 0 ou vazio são false em Pynton

# %%
#12 Peça ao usuário uma temperatura em Kelvin, converta para float, transforme o valor para Celsius e exiba o resultado.
kelvin = float(input("digite uma temperatura em kelvin"))
print(f"a temperatura em kelvin é {kelvin}K em Celsius é: {(kelvin-273.15):.2f}°C")
# Out:
# digite uma temperatura em kelvin32
# a temperatura em kelvin é 32.0K em Celsius é: -241.15°C

# %%
#13 Desenvolva um pequeno programa que receba nome, idade e salário do usuário, convertendo idade para inteiro e salário para float, e mostre todas as informações organizadas na tela.
nome = input(" digite seu nome")
idade = input(" digite sua idade")
salário = float(input(" digite o seu salário"))
print(f"\nNome: {nome}\nidade: {idade}\nSalário: R$ {salário}")
# Out:
#  digite seu nomekaike
#  digite sua idade19
#  digite o seu salário3000.456
#
# Nome: kaike
# idade: 19
# Salário: R$ 3000.456

# %%
#14 Solicite o preço de um produto e o percentual de desconto, converta ambos para float, calcule o valor final com desconto aplicado e exiba o resultado.
preço = float(input("digite o preço:"))
desconto = float(input("digite o desconto(%):"))
preço = preço * ((100-desconto)/100)
print(f"O preço com desconto é: R${preço:.2f}")
# Out:
# digite o preço:100
# digite o desconto(%):10
# O preço com desconto é: R$90.00

# %%
#15 Peça ao usuário que digite um valor numérico, tente convertê-lo para inteiro e,
#caso ocorra erro de conversão, exiba uma mensagem informando que o valor digitado é inválido.
num = input("Digite um valor númerico")
try:
    convertido = int(num)
    print(convertido)
except ValueError:
    print('Valor inválido - Apenas números inteiros, caso seja decimal, tem que converter antes pra float')
# Out:
# Digite um valor númerico2.8
# Valor inválido - Apenas números inteiros, caso seja decimal, tem que converter antes pra float
