# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikeziilskedefaria/ALGESTDADOS20261/blob/main/teste/kaike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("o vasco da gama é o time com maior tradição do mundo")
print("O gigante da colina tem a melhor torcida do mundo")
# Out:
# o vasco da gama é o time com maior tradição do mundo
# O gigante da colina tem a melhor torcida do mundo
